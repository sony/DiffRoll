# %%
import torch
import matplotlib.pyplot as plt

# %%
noise_list = torch.load('outputs/2022-09-28/08-39-16/noise_list.pt')

# %%
plt.imshow(noise_list[-1][0][3][0].T, aspect='auto', origin='lower')
